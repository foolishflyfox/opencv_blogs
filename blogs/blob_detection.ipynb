# %%
import cv2
import numpy as np

im = cv2.imread('./src/blob.jpg', cv2.IMREAD_GRAYSCALE)

# 使用默认参数创建检测器
# opencv 2.x 版本使用
# detector = cv2.SimpleBlobDetector()
# opencv 3.x 或 4.x
detector = cv2.SimpleBlobDetector_create()

keypoints = detector.detect(im)

# 将检测到的斑点用红色圆圈标注
# cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS 保证了圆圈能够和斑点相匹配
im_with_keypoints = cv2.drawKeypoints(im,keypoints,np.array([]),
                                     (0,0,255),
                                     cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

cv2.imwrite("./src/blob_detected.jpg", im_with_keypoints)

# %% [markdown]
# ![](./src/blob_detected.jpg)

# %%
for kp in keypoints:
    print(kp.pt, kp.size)
# Out:
# (382.9203796386719, 393.72802734375) 65.05397033691406
# (377.27374267578125, 304.0808410644531) 65.07413482666016
# (291.0281982421875, 303.90789794921875) 62.643192291259766
# (198.9329071044922, 304.0621643066406) 54.81785202026367
# (284.9353332519531, 229.02984619140625) 58.36680603027344
# (197.0010986328125, 229.02435302734375) 61.46122360229492
# (103.59934997558594, 235.0767364501953) 51.22723388671875
# (377.27532958984375, 229.08175659179688) 65.07415008544922
# (377.2786865234375, 145.0872344970703) 65.0854263305664
# (103.49849700927734, 75.14262390136719) 35.07939147949219
# (189.3389434814453, 75.04774475097656) 43.229652404785156
# (284.87530517578125, 75.12496185302734) 54.531402587890625
# (377.2788391113281, 69.45195007324219) 65.49588012695312
# (284.9555358886719, 145.0391082763672) 64.48941802978516
# (290.9059143066406, 394.3514404296875) 65.0030288696289
# (196.95863342285156, 145.0367889404297) 64.41651916503906

# %%
from PIL import Image

im = cv2.imread('./src/blob.jpg', cv2.IMREAD_GRAYSCALE)

# 使用默认参数创建检测器
# opencv 2.x 版本使用
# detector = cv2.SimpleBlobDetector()
# opencv 3.x 或 4.x
detector = cv2.SimpleBlobDetector_create()

keypoints = detector.detect(im)

# 将检测到的斑点用红色圆圈标注
# cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS 保证了圆圈能够和斑点相匹配
im_with_keypoints = cv2.drawKeypoints(im,keypoints,np.array([]),
                                     (0,0,255),
                                     cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

output_name = "./src/test.jpg"
cv2.imwrite(output_name, im_with_keypoints)
Image.open(output_name)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x480 at 0x116343CC0>
